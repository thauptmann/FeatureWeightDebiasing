# %%
import pandas as pd
from pathlib import Path   
import numpy as np

# %%
result_path = Path("../results/downstream_task")
bias_types = ["less_positive_class"]
less_bias_strengths = ["0.1"]
method_name_replacer = {"uniform": "Uniform", 
                        "kmm": "KMM",
                        "psa": "PSA",
                       # "soft-mrs-linear": "Soft-MRS",
                        "mrs-forest": "MRS",
                        "fw-mrs-temperature": "FW-MRS",
                        "fw-mrs-temperature-svm": "FW-MRS$_{SVM}$",
                        }
data_set_replacer = {"diabetes": "Diabetes",
                    "folktables_employment": "Employment", 
                     "folktables_income": "Income",
                     "bank_marketing": "Bank Marketing",
                     "hr_analytics": "HR Analytic",
                     "german_credit": "German Credit", 
                     "breast_cancer": "Breast Cancer", 
                     "loan_prediction": "Loan",
                    }

data_set_targets = {"diabetes": "Diabetes_binary_relative_bias",
                    "folktables_employment": "Employment_relative_bias", 
                    "folktables_income": "Binary Income_relative_bias",
                    "bank_marketing": "y_relative_bias",
                    "hr_analytics": "target_relative_bias",
                    "german_credit": "class_relative_bias", 
                    "breast_cancer": "class_relative_bias", 
                    "loan_prediction": "Loan_Status_relative_bias",
                    }

# %%
dict_list = []
for dataset in data_set_replacer.keys():
    for bias_type in bias_types:
        for method in method_name_replacer.keys():
            bias_strengths = less_bias_strengths
            for bias_strength in bias_strengths:
                json_file = result_path / dataset / bias_type /  bias_strength/ method / "similarity_results_T.json"
                result_file = pd.read_json(str(json_file))
                dict_list.append(
                    {
                        "Method": method, "Data Set": dataset, 
                        "MMD Mean": result_file["MMDs"]["mean"], 
                        "MMD Std": result_file["MMDs"]["sd"], 
                        "Relative Bias Mean": result_file[data_set_targets[dataset]]["bias mean"], 
                        "Relative Bias Std": result_file[data_set_targets[dataset]]["bias sd"], 
                        "Bias Type": bias_type, "Bias Strength": bias_strength,
                    }
                                )
result_df = pd.DataFrame(data=dict_list)

# %%
for bias_type in bias_types:
    bias_strengths = less_bias_strengths
    for bias_strength in bias_strengths:
        print(f"{bias_type}, {bias_strength}")
        for dataset in data_set_replacer.keys():
            mean_mmd_values = []
            std_mmd_values = []
            for method in result_df["Method"].unique():

                mean_mmd = result_df.loc[(result_df["Method"]==method) & (result_df["Bias Type"]==bias_type) & 
                                                    (result_df["Bias Strength"]==bias_strength) & 
                                                    (result_df["Data Set"]==dataset)]["MMD Mean"].iloc[0]
                mean_mmd_values.append(np.round(mean_mmd, 4))

                std_mmd = result_df.loc[(result_df["Method"]==method) & (result_df["Bias Type"]==bias_type) & 
                                                    (result_df["Bias Strength"]==bias_strength) & 
                                                    (result_df["Data Set"]==dataset)]["MMD Std"].iloc[0]
                std_mmd_values.append(np.round(std_mmd, 3))

                

            print(f"{data_set_replacer[dataset]} \
& ${mean_mmd_values[0]}\\pm{std_mmd_values[0]}$ \
& ${mean_mmd_values[1]}\\pm{std_mmd_values[1]}$ \
& ${mean_mmd_values[2]}\\pm{std_mmd_values[2]}$ \
& ${mean_mmd_values[3]}\\pm{std_mmd_values[3]}$ \
& ${mean_mmd_values[4]}\\pm{std_mmd_values[4]}$ \
& ${mean_mmd_values[5]}\\pm{std_mmd_values[5]}$ \
\\\\")
    print("\n")
# Out:
# less_positive_class, 0.1
# Diabetes & $0.0358\pm0.006$ & $0.0217\pm0.003$ & $0.022\pm0.003$ & $0.0325\pm0.005$ & $0.0319\pm0.005$ & $0.0308\pm0.006$ \\
# Employment & $0.0681\pm0.005$ & $0.0219\pm0.002$ & $0.024\pm0.002$ & $0.0472\pm0.013$ & $0.0465\pm0.014$ & $0.0329\pm0.005$ \\
# Income & $0.064\pm0.005$ & $0.0233\pm0.003$ & $0.0262\pm0.002$ & $0.0501\pm0.011$ & $0.0514\pm0.011$ & $0.0342\pm0.003$ \\
# Bank Marketing & $0.0282\pm0.003$ & $0.0226\pm0.002$ & $0.023\pm0.002$ & $0.027\pm0.002$ & $0.0269\pm0.003$ & $0.0273\pm0.003$ \\
# HR Analytic & $0.0276\pm0.003$ & $0.0184\pm0.002$ & $0.0187\pm0.002$ & $0.0258\pm0.003$ & $0.0246\pm0.003$ & $0.0251\pm0.003$ \\
# German Credit & $0.064\pm0.007$ & $0.0549\pm0.006$ & $0.0561\pm0.007$ & $0.0615\pm0.006$ & $0.0601\pm0.007$ & $0.0631\pm0.01$ \\
# Breast Cancer & $0.3949\pm0.017$ & $0.0429\pm0.009$ & $0.1423\pm0.024$ & $0.2805\pm0.032$ & $0.2701\pm0.043$ & $0.2256\pm0.073$ \\
# Loan & $0.1413\pm0.015$ & $0.0803\pm0.014$ & $0.1004\pm0.015$ & $0.1275\pm0.016$ & $0.1122\pm0.028$ & $0.1105\pm0.02$ \\

# %%
for bias_type in bias_types:
    bias_strengths = less_bias_strengths
    for bias_strength in bias_strengths:
        print(f"{bias_type}, {bias_strength}")
        for dataset in data_set_replacer.keys():
            mean_relative_bias_values = []
            std_relative_bias_values = []
            for method in result_df["Method"].unique():

                mean_relative_bias = result_df.loc[(result_df["Method"]==method) & (result_df["Bias Type"]==bias_type) & 
                                                    (result_df["Bias Strength"]==bias_strength) & 
                                                    (result_df["Data Set"]==dataset)]["Relative Bias Mean"].iloc[0]
                mean_relative_bias_values.append(np.round(mean_relative_bias, 2))

                std_relative_bias = result_df.loc[(result_df["Method"]==method) & (result_df["Bias Type"]==bias_type) & 
                                                    (result_df["Bias Strength"]==bias_strength) & 
                                                    (result_df["Data Set"]==dataset)]["Relative Bias Std"].iloc[0]
                std_relative_bias_values.append(np.round(std_relative_bias, 2))

                

            print(f"{data_set_replacer[dataset]} \
& ${mean_relative_bias_values[0]}\\pm{std_relative_bias_values[0]}$ \
& ${mean_relative_bias_values[1]}\\pm{std_relative_bias_values[1]}$ \
& ${mean_relative_bias_values[2]}\\pm{std_relative_bias_values[2]}$ \
& ${mean_relative_bias_values[3]}\\pm{std_relative_bias_values[3]}$ \
& ${mean_relative_bias_values[4]}\\pm{std_relative_bias_values[4]}$ \
\\\\")
    print("\n")
# Out:
# less_positive_class, 0.1
# Diabetes & $88.76\pm0.03$ & $85.4\pm2.75$ & $86.82\pm0.65$ & $88.56\pm0.2$ & $88.57\pm0.2$ \\
# Employment & $82.99\pm0.0$ & $64.48\pm2.99$ & $72.44\pm1.24$ & $79.36\pm2.13$ & $79.2\pm2.1$ \\
# Income & $83.4\pm0.02$ & $64.46\pm3.41$ & $71.86\pm1.32$ & $80.34\pm1.47$ & $80.41\pm1.58$ \\
# Bank Marketing & $88.77\pm0.03$ & $81.77\pm2.79$ & $83.03\pm1.44$ & $88.49\pm0.22$ & $88.5\pm0.22$ \\
# HR Analytic & $0.8\pm0.58$ & $0.8\pm0.67$ & $0.82\pm0.66$ & $0.75\pm0.51$ & $0.77\pm0.58$ \\
# German Credit & $86.3\pm0.0$ & $80.21\pm3.72$ & $82.5\pm3.92$ & $86.08\pm0.74$ & $86.16\pm0.64$ \\
# Breast Cancer & $75.59\pm0.18$ & $7.08\pm3.25$ & $35.6\pm4.6$ & $57.15\pm4.83$ & $63.04\pm6.08$ \\
# Loan & $6.38\pm5.2$ & $5.0\pm3.31$ & $5.16\pm3.72$ & $5.91\pm5.03$ & $5.94\pm4.97$ \\

# %%
result_df = result_df.replace(method_name_replacer)
result_df
# Out:
#             Method               Data Set  MMD Mean   MMD Std  \
# 0          Uniform               diabetes  0.035790  0.006027
# 1              KMM               diabetes  0.021661  0.003101
# 2              PSA               diabetes  0.021974  0.002963
# 3              MRS               diabetes  0.032462  0.005429
# 4           FW-MRS               diabetes  0.031861  0.005348
# 5   FW-MRS$_{SVM}$               diabetes  0.030843  0.005947
# 6          Uniform  folktables_employment  0.068065  0.005092
# 7              KMM  folktables_employment  0.021865  0.001573
# 8              PSA  folktables_employment  0.024042  0.001788
# 9              MRS  folktables_employment  0.047241  0.012916
# 10          FW-MRS  folktables_employment  0.046527  0.014330
# 11  FW-MRS$_{SVM}$  folktables_employment  0.032905  0.005117
# 12         Uniform      folktables_income  0.063995  0.005134
# 13             KMM      folktables_income  0.023319  0.002842
# 14             PSA      folktables_income  0.026209  0.002453
# 15             MRS      folktables_income  0.050118  0.010829
# 16          FW-MRS      folktables_income  0.051369  0.010919
# 17  FW-MRS$_{SVM}$      folktables_income  0.034201  0.002862
# 18         Uniform         bank_marketing  0.028176  0.002776
# 19             KMM         bank_marketing  0.022634  0.001817
# 20             PSA         bank_marketing  0.022958  0.001663
# 21             MRS         bank_marketing  0.026982  0.002461
# 22          FW-MRS         bank_marketing  0.026948  0.002530
# 23  FW-MRS$_{SVM}$         bank_marketing  0.027275  0.002634
# 24         Uniform           hr_analytics  0.027595  0.003097
# 25             KMM           hr_analytics  0.018422  0.002220
# 26             PSA           hr_analytics  0.018713  0.002327
# 27             MRS           hr_analytics  0.025805  0.002817
# 28          FW-MRS           hr_analytics  0.024579  0.002736
# 29  FW-MRS$_{SVM}$           hr_analytics  0.025066  0.003186
# 30         Uniform          german_credit  0.064033  0.006621
# 31             KMM          german_credit  0.054874  0.005913
# 32             PSA          german_credit  0.056055  0.006544
# 33             MRS          german_credit  0.061532  0.006233
# 34          FW-MRS          german_credit  0.060059  0.007168
# 35  FW-MRS$_{SVM}$          german_credit  0.063061  0.010146
# 36         Uniform          breast_cancer  0.394904  0.017140
# 37             KMM          breast_cancer  0.042864  0.009061
# 38             PSA          breast_cancer  0.142252  0.023988
# 39             MRS          breast_cancer  0.280492  0.032003
# 40          FW-MRS          breast_cancer  0.270129  0.043125
# 41  FW-MRS$_{SVM}$          breast_cancer  0.225623  0.073111
# 42         Uniform        loan_prediction  0.141282  0.015288
# 43             KMM        loan_prediction  0.080285  0.014295
# 44             PSA        loan_prediction  0.100370  0.014911
# 45             MRS        loan_prediction  0.127454  0.016340
# 46          FW-MRS        loan_prediction  0.112250  0.027811
# 47  FW-MRS$_{SVM}$        loan_prediction  0.110480  0.020158
#
#     Relative Bias Mean  Relative Bias Std            Bias Type Bias Strength
# 0            88.764886       2.972893e-02  less_positive_class           0.1
# 1            85.403825       2.745357e+00  less_positive_class           0.1
# 2            86.818399       6.500400e-01  less_positive_class           0.1
# 3            88.562630       1.970144e-01  less_positive_class           0.1
# 4            88.566419       2.043089e-01  less_positive_class           0.1
# 5            88.368641       2.298720e-01  less_positive_class           0.1
# 6            82.985481       5.684342e-14  less_positive_class           0.1
# 7            64.483977       2.991754e+00  less_positive_class           0.1
# 8            72.442898       1.238853e+00  less_positive_class           0.1
# 9            79.360640       2.132048e+00  less_positive_class           0.1
# 10           79.200759       2.096439e+00  less_positive_class           0.1
# 11           79.022628       6.167642e-01  less_positive_class           0.1
# 12           83.396447       1.534683e-02  less_positive_class           0.1
# 13           64.457094       3.410984e+00  less_positive_class           0.1
# 14           71.864346       1.317663e+00  less_positive_class           0.1
# 15           80.343288       1.468238e+00  less_positive_class           0.1
# 16           80.411418       1.578545e+00  less_positive_class           0.1
# 17           79.491775       5.088089e-01  less_positive_class           0.1
# 18           88.770556       3.340664e-02  less_positive_class           0.1
# 19           81.765934       2.794034e+00  less_positive_class           0.1
# 20           83.031803       1.439390e+00  less_positive_class           0.1
# 21           88.487270       2.173149e-01  less_positive_class           0.1
# 22           88.496742       2.192651e-01  less_positive_class           0.1
# 23           88.510104       2.559007e-01  less_positive_class           0.1
# 24            0.804678       5.828456e-01  less_positive_class           0.1
# 25            0.804914       6.679480e-01  less_positive_class           0.1
# 26            0.823168       6.597071e-01  less_positive_class           0.1
# 27            0.751135       5.148039e-01  less_positive_class           0.1
# 28            0.771579       5.785193e-01  less_positive_class           0.1
# 29            0.755042       6.562267e-01  less_positive_class           0.1
# 30           86.301370       7.105427e-14  less_positive_class           0.1
# 31           80.209430       3.717328e+00  less_positive_class           0.1
# 32           82.495010       3.917639e+00  less_positive_class           0.1
# 33           86.078065       7.417124e-01  less_positive_class           0.1
# 34           86.156166       6.354643e-01  less_positive_class           0.1
# 35           85.993208       5.574075e-01  less_positive_class           0.1
# 36           75.586060       1.777548e-01  less_positive_class           0.1
# 37            7.084018       3.250241e+00  less_positive_class           0.1
# 38           35.602627       4.602077e+00  less_positive_class           0.1
# 39           57.150645       4.826247e+00  less_positive_class           0.1
# 40           63.041278       6.083362e+00  less_positive_class           0.1
# 41           55.305947       7.882261e+00  less_positive_class           0.1
# 42            6.381475       5.203385e+00  less_positive_class           0.1
# 43            5.000049       3.309805e+00  less_positive_class           0.1
# 44            5.162500       3.724999e+00  less_positive_class           0.1
# 45            5.905138       5.032396e+00  less_positive_class           0.1
# 46            5.935917       4.973200e+00  less_positive_class           0.1
# 47            5.999432       4.810892e+00  less_positive_class           0.1

# %%
result_df["Rank MMD"] = result_df.groupby("Data Set")["MMD Mean"].rank(ascending=True)
result_df["Rank Relative Bias"] = result_df.groupby("Data Set")["Relative Bias Mean"].rank(ascending=True)
result_df[["Method", "Rank MMD", "Rank Relative Bias"]].groupby("Method").mean()
# Out:
#                 Rank MMD  Rank Relative Bias
# Method
# FW-MRS             3.750               4.375
# FW-MRS$_{SVM}$     3.625               3.375
# KMM                1.000               1.500
# MRS                4.625               3.500
# PSA                2.000               2.500
# Uniform            6.000               5.750
