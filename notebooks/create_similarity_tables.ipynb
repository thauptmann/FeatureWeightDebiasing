# %%
import pandas as pd
from pathlib import Path   
import numpy as np

# %%
result_path = Path("../results/downstream_task")
bias_types = ["less_positive_class"]
less_bias_strengths = ["0.1"]
method_name_replacer = {"uniform": "Uniform", 
                        "kmm": "KMM",
                        "psa": "PSA",
                        "soft-mrs-linear": "Soft-MRS",
                        "mrs-forest": "MRS",
                        "fw-mrs-temperature": "FW-MRS",
                        "fw-mrs-temperature-svm": "FW-MRS$_{SVM}$",
                        }
data_set_replacer = {"diabetes": "Diabetes",
                    "folktables_employment": "Employment", 
                     "folktables_income": "Income",
                     "bank_marketing": "Bank Marketing",
                     "hr_analytics": "HR Analytic",
                     "german_credit": "German Credit", 
                     "breast_cancer": "Breast Cancer", 
                     "loan_prediction": "Loan",
                    }

data_set_targets = {"diabetes": "Diabetes_binary_relative_bias",
                    "folktables_employment": "Employment_relative_bias", 
                    "folktables_income": "Binary Income_relative_bias",
                    "bank_marketing": "y_relative_bias",
                    "hr_analytics": "target_relative_bias",
                    "german_credit": "class_relative_bias", 
                    "breast_cancer": "class_relative_bias", 
                    "loan_prediction": "Loan_Status_relative_bias",
                    }

# %%
dict_list = []
for dataset in data_set_replacer.keys():
    for bias_type in bias_types:
        for method in method_name_replacer.keys():
            bias_strengths = less_bias_strengths
            for bias_strength in bias_strengths:
                json_file = result_path / dataset / bias_type /  bias_strength/ method / "similarity_results_T.json"
                result_file = pd.read_json(str(json_file))
                dict_list.append(
                    {
                        "Method": method, "Data Set": dataset, 
                        "MMD Mean": result_file["MMDs"]["mean"], 
                        "MMD Std": result_file["MMDs"]["sd"], 
                        "Bias Type": bias_type, "Bias Strength": bias_strength,
                    }
                                )
result_df = pd.DataFrame(data=dict_list)

# %%
for bias_type in bias_types:
    bias_strengths = less_bias_strengths
    for bias_strength in bias_strengths:
        print(f"{bias_type}, {bias_strength}")
        for dataset in data_set_replacer.keys():
            mean_mmd_values = []
            std_mmd_values = []
            for method in result_df["Method"].unique():

                mean_mmd = result_df.loc[(result_df["Method"]==method) & (result_df["Bias Type"]==bias_type) & 
                                                    (result_df["Bias Strength"]==bias_strength) & 
                                                    (result_df["Data Set"]==dataset)]["MMD Mean"].iloc[0]
                mean_mmd_values.append(np.round(mean_mmd, 4))

                std_mmd = result_df.loc[(result_df["Method"]==method) & (result_df["Bias Type"]==bias_type) & 
                                                    (result_df["Bias Strength"]==bias_strength) & 
                                                    (result_df["Data Set"]==dataset)]["MMD Std"].iloc[0]
                std_mmd_values.append(np.round(std_mmd, 3))

                

            print(f"{data_set_replacer[dataset]} \
& ${mean_mmd_values[0]}\\pm{std_mmd_values[0]}$ \
& ${mean_mmd_values[1]}\\pm{std_mmd_values[1]}$ \
& ${mean_mmd_values[2]}\\pm{std_mmd_values[2]}$ \
& ${mean_mmd_values[3]}\\pm{std_mmd_values[3]}$ \
& ${mean_mmd_values[4]}\\pm{std_mmd_values[4]}$ \
& ${mean_mmd_values[5]}\\pm{std_mmd_values[5]}$ \
& ${mean_mmd_values[6]}\\pm{std_mmd_values[6]}$ \
& \\\\")
    print("\n")
# Out:
# less_positive_class, 0.1
# Diabetes & $0.0358\pm0.006$ & $0.0217\pm0.003$ & $0.022\pm0.003$ & $0.0217\pm0.003$ & $0.0325\pm0.005$ & $0.0319\pm0.005$ & $0.0308\pm0.006$ & \\
# Employment & $0.0681\pm0.005$ & $0.0219\pm0.002$ & $0.024\pm0.002$ & $0.022\pm0.001$ & $0.0472\pm0.013$ & $0.0465\pm0.014$ & $0.0329\pm0.005$ & \\
# Income & $0.064\pm0.005$ & $0.0233\pm0.003$ & $0.0262\pm0.002$ & $0.023\pm0.002$ & $0.0501\pm0.011$ & $0.0514\pm0.011$ & $0.0342\pm0.003$ & \\
# Bank Marketing & $0.0282\pm0.003$ & $0.0226\pm0.002$ & $0.023\pm0.002$ & $0.0226\pm0.002$ & $0.027\pm0.002$ & $0.0269\pm0.003$ & $0.0273\pm0.003$ & \\
# HR Analytic & $0.0276\pm0.003$ & $0.0184\pm0.002$ & $0.0187\pm0.002$ & $0.0183\pm0.002$ & $0.0258\pm0.003$ & $0.0246\pm0.003$ & $0.0251\pm0.003$ & \\
# German Credit & $0.064\pm0.007$ & $0.0549\pm0.006$ & $0.0561\pm0.007$ & $0.0547\pm0.006$ & $0.0615\pm0.006$ & $0.0601\pm0.007$ & $0.0631\pm0.01$ & \\
# ...

# %%
method_name_replacer = {"uniform": "Uniform", 
                        "kmm": "KMM",
                        "psa": "PSA",
                        "soft-mrs-linear": "Soft-MRS",
                        "mrs-forest": "MRS",
                        }
dict_list = []
for dataset in data_set_replacer.keys():
    for bias_type in bias_types:
        for method in method_name_replacer.keys():
            bias_strengths = less_bias_strengths
            for bias_strength in bias_strengths:
                json_file = result_path / dataset / bias_type /  bias_strength/ method / "similarity_results_T.json"
                result_file = pd.read_json(str(json_file))
                dict_list.append(
                    {
                        "Method": method, "Data Set": dataset, 
                        "Relative Bias Mean": result_file[data_set_targets[dataset]]["bias mean"], 
                        "Relative Bias Std": result_file[data_set_targets[dataset]]["bias sd"], 
                        "Bias Type": bias_type, "Bias Strength": bias_strength,
                    }
                                )
result_df_relative_bias = pd.DataFrame(data=dict_list)

# %%
for bias_type in bias_types:
    bias_strengths = less_bias_strengths
    for bias_strength in bias_strengths:
        print(f"{bias_type}, {bias_strength}")
        for dataset in data_set_replacer.keys():
            mean_relative_bias_values = []
            std_relative_bias_values = []
            for method in result_df_relative_bias["Method"].unique():

                mean_relative_bias = result_df_relative_bias.loc[(result_df_relative_bias["Method"]==method) & (result_df_relative_bias["Bias Type"]==bias_type) & 
                                                    (result_df_relative_bias["Bias Strength"]==bias_strength) & 
                                                    (result_df_relative_bias["Data Set"]==dataset)]["Relative Bias Mean"].iloc[0]
                mean_relative_bias_values.append(np.round(mean_relative_bias, 2))

                std_relative_bias = result_df_relative_bias.loc[(result_df_relative_bias["Method"]==method) & (result_df_relative_bias["Bias Type"]==bias_type) & 
                                                    (result_df_relative_bias["Bias Strength"]==bias_strength) & 
                                                    (result_df_relative_bias["Data Set"]==dataset)]["Relative Bias Std"].iloc[0]
                std_relative_bias_values.append(np.round(std_relative_bias, 2))

                

            print(f"{data_set_replacer[dataset]} \
& ${mean_relative_bias_values[0]}\\pm{std_relative_bias_values[0]}$ \
& ${mean_relative_bias_values[1]}\\pm{std_relative_bias_values[1]}$ \
& ${mean_relative_bias_values[2]}\\pm{std_relative_bias_values[2]}$ \
& ${mean_relative_bias_values[3]}\\pm{std_relative_bias_values[3]}$ \
& ${mean_relative_bias_values[4]}\\pm{std_relative_bias_values[4]}$ \
& \\\\")
    print("\n")
# Out:
# less_positive_class, 0.1
# Diabetes & $88.76\pm0.03$ & $85.4\pm2.75$ & $86.82\pm0.65$ & $85.82\pm1.29$ & $88.56\pm0.2$ & \\
# Employment & $82.99\pm0.0$ & $64.48\pm2.99$ & $72.44\pm1.24$ & $65.96\pm1.79$ & $79.36\pm2.13$ & \\
# Income & $83.4\pm0.02$ & $64.46\pm3.41$ & $71.86\pm1.32$ & $65.77\pm1.78$ & $80.34\pm1.47$ & \\
# Bank Marketing & $88.77\pm0.03$ & $81.77\pm2.79$ & $83.03\pm1.44$ & $82.07\pm1.51$ & $88.49\pm0.22$ & \\
# HR Analytic & $88.31\pm0.02$ & $84.37\pm2.11$ & $85.27\pm0.69$ & $83.88\pm1.05$ & $88.05\pm0.2$ & \\
# German Credit & $86.3\pm0.0$ & $80.21\pm3.72$ & $82.5\pm3.92$ & $81.2\pm3.2$ & $86.08\pm0.74$ & \\
# Breast Cancer & $75.59\pm0.18$ & $7.08\pm3.25$ & $35.6\pm4.6$ & $7.74\pm2.4$ & $57.15\pm4.83$ & \\
# Loan & $6.38\pm5.2$ & $5.0\pm3.31$ & $5.16\pm3.72$ & $4.99\pm3.22$ & $5.91\pm5.03$ & \\

# %%
result_df_relative_bias = result_df_relative_bias.replace(method_name_replacer)
result_df_relative_bias
# Out:
#       Method               Data Set  Relative Bias Mean  Relative Bias Std  \
# 0    Uniform               diabetes           88.764886       2.972893e-02
# 1        KMM               diabetes           85.403825       2.745357e+00
# 2        PSA               diabetes           86.818399       6.500400e-01
# 3   Soft-MRS               diabetes           85.821534       1.290378e+00
# 4        MRS               diabetes           88.562630       1.970144e-01
# 5    Uniform  folktables_employment           82.985481       5.684342e-14
# 6        KMM  folktables_employment           64.483977       2.991754e+00
# 7        PSA  folktables_employment           72.442898       1.238853e+00
# 8   Soft-MRS  folktables_employment           65.959261       1.787170e+00
# 9        MRS  folktables_employment           79.360640       2.132048e+00
# 10   Uniform      folktables_income           83.396447       1.534683e-02
# ...

# %%
result_df["Rank MMD"] = result_df.groupby("Data Set")["MMD Mean"].rank(ascending=True)
result_df_relative_bias["Rank Relative Bias"] = result_df_relative_bias.groupby("Data Set")["Relative Bias Mean"].rank(ascending=True)
print(result_df[["Method", "Rank MMD"]].groupby("Method").mean())
print(result_df_relative_bias[["Method", "Rank Relative Bias"]].groupby("Method").mean())
# Out:
#                         Rank MMD
# Method
# fw-mrs-temperature         4.750
# fw-mrs-temperature-svm     4.625
# kmm                        1.500
# mrs-forest                 5.625
# psa                        3.000
# soft-mrs-linear            1.500
# uniform                    7.000
#           Rank Relative Bias
# Method
# KMM                     1.25
# MRS                     4.00
# PSA                     3.00
# Soft-MRS                1.75
# Uniform                 5.00
